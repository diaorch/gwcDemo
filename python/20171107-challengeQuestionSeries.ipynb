# %% [markdown]
# States' centroid accorinding to Wikipedia: https://en.wikipedia.org/wiki/List_of_geographic_centers_of_the_United_States

# %%
centroid_coordinates = {'AL': [32.7794, 86.8287], 'AK': [64.0685, 152.2782], 'AZ': [34.2744, 111.6602], 'AR': [34.8938, 92.4426], 'CA': [37.1841, 119.4696], 'CO': [38.9972, 105.5478], 'CT': [41.6219, 72.7273], 'DE': [38.9896, 75.505], 'DC': [38.9101, 77.0147], 'FL': [28.6305, 82.4497], 'GA': [32.6415, 83.4426], 'HI': [20.2927, 156.3737], 'ID': [44.3509, 114.613], 'IL': [40.0417, 89.1965], 'IN': [39.8942, 86.2816], 'IA': [42.0751, 93.496], 'KS': [38.4937, 98.3804], 'KY': [37.5347, 85.3021], 'LA': [31.0689, 91.9968], 'ME': [45.3695, 69.2428], 'MD': [39.055, 76.7909], 'MA': [42.2596, 71.8083], 'MI': [44.3467, 85.4102], 'MN': [46.2807, 94.3053], 'MS': [32.7364, 89.6678], 'MO': [38.3566, 92.458], 'MT': [47.0527, 109.6333], 'NE': [41.5378, 99.7951], 'NV': [39.3289, 116.6312], 'NH': [43.6805, 71.5811], 'NJ': [40.1907, 74.6728], 'NM': [34.4071, 106.1126], 'NY': [42.9538, 75.5268], 'NC': [35.5557, 79.3877], 'ND': [47.4501, 100.4659], 'OH': [40.2862, 82.7937], 'OK': [35.5889, 97.4943], 'OR': [43.9336, 120.5583], 'PA': [40.8781, 77.7996], 'RI': [41.6762, 71.5562], 'SC': [33.9169, 80.8964], 'SD': [44.4443, 100.2263], 'TN': [35.858, 86.3505], 'TX': [31.4757, 99.3312], 'UT': [39.3055, 111.6703], 'VT': [44.0687, 72.6658], 'VA': [37.5215, 78.8537], 'WA': [47.3826, 120.4472], 'WV': [38.6409, 80.6227], 'WI': [44.6243, 89.9941], 'WY': [42.9957, 107.5512]}

# %%
type(centroid_coordinates)
# Out:
# dict

# %% [markdown]
# Find the coordinate of centroid of Michigan

# %%
centroid_coordinates['MI']
# Out:
# [44.3467, 85.4102]

# %% [markdown]
# Plotting centroids

# %%
centroid_coordinates.values()
# Out:
# dict_values([[32.7794, 86.8287], [64.0685, 152.2782], [34.2744, 111.6602], [34.8938, 92.4426], [37.1841, 119.4696], [38.9972, 105.5478], [41.6219, 72.7273], [38.9896, 75.505], [38.9101, 77.0147], [28.6305, 82.4497], [32.6415, 83.4426], [20.2927, 156.3737], [44.3509, 114.613], [40.0417, 89.1965], [39.8942, 86.2816], [42.0751, 93.496], [38.4937, 98.3804], [37.5347, 85.3021], [31.0689, 91.9968], [45.3695, 69.2428], [39.055, 76.7909], [42.2596, 71.8083], [44.3467, 85.4102], [46.2807, 94.3053], [32.7364, 89.6678], [38.3566, 92.458], [47.0527, 109.6333], [41.5378, 99.7951], [39.3289, 116.6312], [43.6805, 71.5811], [40.1907, 74.6728], [34.4071, 106.1126], [42.9538, 75.5268], [35.5557, 79.3877], [47.4501, 100.4659], [40.2862, 82.7937], [35.5889, 97.4943], [43.9336, 120.5583], [40.8781, 77.7996], [41.6762, 71.5562], [33.9169, 80.8964], [44.4443, 100.2263], [35.858, 86.3505], [31.4757, 99.3312], [39.3055, 111.6703], [44.0687, 72.6658], [37.5215, 78.8537], [47.3826, 120.4472], [38.6409, 80.6227
# ...

# %%
plotData = {'x':[], 'y':[], 'label':[]}
for state, coordinates in centroid_coordinates.items():
    plotData["y"].append(coordinates[0])
    plotData["x"].append(coordinates[1])
    plotData["label"].append(state)

# %%
state_names = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
state_centroid_W = [86.8287, 152.2782, 111.6602, 92.4426, 119.4696, 105.5478, 72.7273, 75.505, 77.0147, 82.4497, 83.4426, 156.3737, 114.613, 89.1965, 86.2816, 93.496, 98.3804, 85.3021, 91.9968, 69.2428, 76.7909, 71.8083, 85.4102, 94.3053, 89.6678, 92.458, 109.6333, 99.7951, 116.6312, 71.5811, 74.6728, 106.1126, 75.5268, 79.3877, 100.4659, 82.7937, 97.4943, 120.5583, 77.7996, 71.5562, 80.8964, 100.2263, 86.3505, 99.3312, 111.6703, 72.6658, 78.8537, 120.4472, 80.6227, 89.9941, 107.5512]
state_centroid_N = [32.7794,64.0685,34.2744,34.8938,37.1841,38.9972,41.6219,38.9896,38.9101,28.6305,32.6415,20.2927,44.3509,40.0417,39.8942,42.0751,38.4937,37.5347,31.0689,45.3695,39.055,42.2596,44.3467,46.2807,32.7364,38.3566,47.0527,41.5378,39.3289,43.6805,40.1907,34.4071,42.9538,35.5557,47.4501,40.2862,35.5889,43.9336,40.8781,41.6762,33.9169,44.4443,35.858,31.4757,39.3055,44.0687,37.5215,47.3826,38.6409,44.6243,42.9957]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# display scatter plot data
plt.figure(figsize=(16,9))
plt.title('State centroids', fontsize=20)
plt.xlabel('W', fontsize=15)
plt.ylabel('N', fontsize=15)
plt.scatter(state_centroid_W, state_centroid_N, marker = 'o')
plt.axis([max(state_centroid_W), min(state_centroid_W), min(state_centroid_N), max(state_centroid_N)])

# add label
for label, x, y in zip(state_names, state_centroid_W,state_centroid_N):
    plt.annotate(label, xy = (x, y))

# %%
region_to_state = {'California': ['CA'],
                   'Midwest': ['ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'MI', 'IN', 'OH'],
                   'Northeast': ['MA', 'MD', 'PA', 'DC', 'RI', 'ME', 'AK', 'NH', 'VT', 'DE', 'NJ', 'HI', 'CT', 'NY'],
                   'South': ['OK', 'TX', 'AR', 'LA', 'KY', 'TN', 'MS', 'AL', 'FL', 'WV', 'VA', 'NC', 'SC', 'GA'],
                   'West': ['WA', 'OR', 'NV', 'ID', 'UT', 'AZ', 'MT', 'WY', 'CO', 'NM'],
                   'Other': ['HI', 'AK']
                  }

# %%
state_to_region = []
for state_abbreviation in state_names:
    for key in region_to_state:
        if (state_abbreviation in region_to_state[key]):
            state_to_region = state_to_region + [key]
state_to_region
# Out:
# ['South',
#  'Northeast',
#  'Other',
#  'West',
#  'South',
#  'California',
#  'West',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'South',
#  'South',
#  'Northeast',
#  'Other',
#  'West',
#  'Midwest',
#  'Midwest',
#  'Midwest',
#  'Midwest',
#  'South',
#  'South',
#  'Northeast',
#  'Northeast',
#  'Northeast',
#  'Midwest',
#  'Midwest',
#  'South',
#  'Midwest',
#  'West',
#  'Midwest',
#  'West',
#  'Northeast',
#  'Northeast',
#  'West',
#  'Northeast',
#  'South',
#  'Midwest',
#  'Midwest',
#  'South',
#  'West',
#  'Northeast',
#  'Northeast',
#  'South',
#  'Midwest',
#  'South',
#  'South',
#  'West',
#  'Northeast',
#  'South',
#  'West',
#  'South',
#  'Midwest',
#  'West']

# %%
# state_to_region = ['South','Northeast','Other','West','South','California','West','Northeast','Northeast','Northeast','South','South','Northeast','Other','West','Midwest','Midwest','Midwest','Midwest','South','South','Northeast','Northeast','Northeast','Midwest','Midwest','South','Midwest','West','Midwest','West','Northeast','Northeast','West','Northeast','South','Midwest','Midwest','South','West','Northeast','Northeast','South','Midwest','South','South','West','Northeast','South','West','South',]

# %%
region_to_color = []
for region in state_to_region:
    if (region == 'South'):
        region_to_color += ['yellow']
    elif (region == 'Northeast'):
        region_to_color += ['blue']
    elif (region == 'West'):
        region_to_color += ['green']
    elif (region == 'Midwest'):
        region_to_color += ['red']
    elif (region == 'California'):
        region_to_color += ['cyan']
    else:
        region_to_color += ['black']

# %%
region_to_color
# Out:
# ['yellow',
#  'blue',
#  'black',
#  'green',
#  'yellow',
#  'cyan',
#  'green',
#  'blue',
#  'blue',
#  'blue',
#  'yellow',
#  'yellow',
#  'blue',
#  'black',
#  'green',
#  'red',
#  'red',
#  'red',
#  'red',
#  'yellow',
#  'yellow',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'yellow',
#  'red',
#  'green',
#  'red',
#  'green',
#  'blue',
#  'blue',
#  'green',
#  'blue',
#  'yellow',
#  'red',
#  'red',
#  'yellow',
#  'green',
#  'blue',
#  'blue',
#  'yellow',
#  'red',
#  'yellow',
#  'yellow',
#  'green',
#  'blue',
#  'yellow',
#  'green',
#  'yellow',
#  'red',
#  'green']

# %%
plt.figure(figsize=(16,9))
plt.title('State centroids', fontsize=20)
plt.xlabel('W', fontsize=15)
plt.ylabel('N', fontsize=15)
plt.scatter(state_centroid_W, state_centroid_N, marker = 'o', c = region_to_color)
plt.axis([max(state_centroid_W), min(state_centroid_W), min(state_centroid_N), max(state_centroid_N)])
# Out:
# [156.3737, 69.2428, 20.2927, 64.0685]

# %% [markdown]
# ![state_map](https://upload.wikimedia.org/wikipedia/commons/1/13/Map_of_USA_States_with_names_white.svg)

# %% [markdown]
# Dictionary
# COLI: cost of living index

# %%
coli = {'Mississippi': 84.2, 'Arkansas': 87.7, 'Michigan': 89, 'Missouri': 89.2, 'Oklahoma': 89.3, 'Iowa': 90, 'Tennessee': 90.1, 'Alabama': 90.2, 'Kansas': 90.7, 'Georgia': 91.1, 'Texas': 91.6, 'Ohio': 91.7, 'Nebraska': 92.3, 'New Mexico': 92.5, 'Indiana': 92.5, 'Idaho': 93.3, 'Kentucky': 93.7, 'North Carolina': 93.9, 'Louisiana': 93.9, 'Wyoming': 95.5, 'Wisconsin': 95.6, 'South Dakota': 95.7, 'Arizona': 96, 'Illinois': 96.6, 'Utah': 96.7, 'West Virginia': 96.8, 'South Carolina': 98.4, 'Florida': 98.9, 'Minnesota': 99, 'North Dakota': 99.9, 'Montana': 101.2, 'Pennsylvania': 101.5, 'Virginia': 101.9, 'Delaware': 103.5, 'Colorado': 104, 'Nevada': 106.6, 'Washington': 107.6, 'Maine': 113.5, 'New Hampshire': 113.7, 'Vermont': 120.2, 'New Jersey': 120.5, 'Rhode Island': 123, 'Connecticut': 124.9, 'Oregon': 125.7, 'Massachusetts': 127.3, 'Maryland': 128.4, 'Alaska': 131.9, 'New York': 134.1, 'California': 140.5, 'District of Columbia': 157.4, 'Hawaii': 188.4}
coli
# Out:
# {'Alabama': 90.2,
#  'Alaska': 131.9,
#  'Arizona': 96,
#  'Arkansas': 87.7,
#  'California': 140.5,
#  'Colorado': 104,
#  'Connecticut': 124.9,
#  'Delaware': 103.5,
#  'District of Columbia': 157.4,
#  'Florida': 98.9,
#  'Georgia': 91.1,
#  'Hawaii': 188.4,
#  'Idaho': 93.3,
#  'Illinois': 96.6,
#  'Indiana': 92.5,
#  'Iowa': 90,
#  'Kansas': 90.7,
#  'Kentucky': 93.7,
#  'Louisiana': 93.9,
#  'Maine': 113.5,
#  'Maryland': 128.4,
#  'Massachusetts': 127.3,
#  'Michigan': 89,
#  'Minnesota': 99,
#  'Mississippi': 84.2,
#  'Missouri': 89.2,
#  'Montana': 101.2,
#  'Nebraska': 92.3,
#  'Nevada': 106.6,
#  'New Hampshire': 113.7,
#  'New Jersey': 120.5,
#  'New Mexico': 92.5,
#  'New York': 134.1,
#  'North Carolina': 93.9,
#  'North Dakota': 99.9,
#  'Ohio': 91.7,
#  'Oklahoma': 89.3,
#  'Oregon': 125.7,
#  'Pennsylvania': 101.5,
#  'Rhode Island': 123,
#  'South Carolina': 98.4,
#  'South Dakota': 95.7,
#  'Tennessee': 90.1,
#  'Texas': 91.6,
#  'Utah': 96.7,
#  'Vermont': 120.2,
# ...

# %%
state_abbr = {'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'District of Columbia': 'DC', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'}
state_abbr
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
# ...

# %%
state_region = {'California': ['CA'], 
                'West': ['WA', 'OR', 'NV', 'ID', 'UT', 'AZ', 'MT', 'WY', 'CO', 'NM'],
                'Midwest': ['ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'MI', 'IN', 'OH'], 
                'South': ['OK', 'TX', 'AR', 'LA', 'KY', 'TN', 'MS', 'AL', 'FL', 'WV', 'VA', 'NC', 'SC', 'GA'], 
                'Northeast': []
               }

# %%
for key,value in state_region.items():
    print(key)
    for state_name in value:
        print(state_name)
# Out:
# California
# CA
# West
# WA
# OR
# NV
# ID
# UT
# AZ
# MT
# WY
# CO
# NM
# Midwest
# ND
# SD
# NE
# KS
# MN
# IA
# MO
# WI
# IL
# MI
# IN
# OH
# South
# OK
# TX
# AR
# LA
# KY
# TN
# MS
# AL
# FL
# WV
# VA
# NC
# SC
# GA
# Northeast

# %%
included = []
for key,value in state_region.items():
    print(key)
    included = included + value
print(included)
# Out:
# California
# West
# Midwest
# South
# Northeast
# ['CA', 'WA', 'OR', 'NV', 'ID', 'UT', 'AZ', 'MT', 'WY', 'CO', 'NM', 'ND', 'SD', 'NE', 'KS', 'MN', 'IA', 'MO', 'WI', 'IL', 'MI', 'IN', 'OH', 'OK', 'TX', 'AR', 'LA', 'KY', 'TN', 'MS', 'AL', 'FL', 'WV', 'VA', 'NC', 'SC', 'GA']

# %%
list(set(state_abbr.values()).difference(set(included)))
# Out:
# ['MA',
#  'MD',
#  'PA',
#  'DC',
#  'RI',
#  'ME',
#  'AK',
#  'NH',
#  'VT',
#  'DE',
#  'NJ',
#  'HI',
#  'CT',
#  'NY']

# %%
state_region['Northeast'] = list(set(state_abbr.values()).difference(set(included)))
state_region
# Out:
# {'California': ['CA'],
#  'Midwest': ['ND',
#   'SD',
#   'NE',
#   'KS',
#   'MN',
#   'IA',
#   'MO',
#   'WI',
#   'IL',
#   'MI',
#   'IN',
#   'OH'],
#  'Northeast': ['MA',
#   'MD',
#   'PA',
#   'DC',
#   'RI',
#   'ME',
#   'AK',
#   'NH',
#   'VT',
#   'DE',
#   'NJ',
#   'HI',
#   'CT',
#   'NY'],
#  'South': ['OK',
#   'TX',
#   'AR',
#   'LA',
#   'KY',
#   'TN',
#   'MS',
#   'AL',
#   'FL',
#   'WV',
#   'VA',
#   'NC',
#   'SC',
#   'GA'],
#  'West': ['WA', 'OR', 'NV', 'ID', 'UT', 'AZ', 'MT', 'WY', 'CO', 'NM']}

# %% [markdown]
# http://thomaslegion.net/uscensusbureauregionsthewestthemidwestthesouthandthenortheast.html
# ![region_map](http://thomaslegion.net/sitebuildercontent/sitebuilderpictures/map_of_usa_regions_by_us_census_bureau.jpg)

# %% [markdown]
# for loop
